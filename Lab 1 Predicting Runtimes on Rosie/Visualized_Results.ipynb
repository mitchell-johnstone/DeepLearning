# %% [markdown]
# # Lab 1

# %% [markdown]
# ## Setup / Imports

# %%
from matplotlib import pyplot as plt 
import numpy as np 
import os

# %% [markdown]
# ## Running Statistics:
# TBD

# %% [markdown]
# ## GAN Image Results

# %%
imgs = np.load('imgs.npy') 
plt.imshow(imgs)

# %% [markdown]
# ## Loss Plots

# %%
losses = np.load('losses.npy') 
plt.plot(losses[:,0],losses[:,1:3]) 
plt.legend(['discriminator','generator']) 
plt.xlabel('epoch') 
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# Funky Generator loss plot. Shouldn't that be going down?
